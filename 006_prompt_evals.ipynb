# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")

    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
        Please solve the following task:

        {test_case["task"]}
        """
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Region Extractor\n\n```python\nimport re\nfrom urllib.parse import urlparse\n\ndef extract_aws_region_from_s3_uri(s3_uri: str) -> str:\n    \"\"\"\n    Extracts the AWS region from an S3 bucket URI.\n    \n    The region is assumed to be the last hyphen-separated component \n    of the bucket name before any path segments.\n    \n    Args:\n        s3_uri: S3 URI in format 's3://bucket-name/path' or 's3://bucket-name-region/path'\n        \n    Returns:\n        The AWS region string, or an empty string if no region is found\n        \n    Examples:\n        >>> extract_aws_region_from_s3_uri('s3://my-bucket-us-west-2/path')\n        'us-west-2'\n        >>> extract_aws_region_from_s3_uri('s3://data-eu-central-1/folder/file.txt')\n        'eu-central-1'\n        >>> extract_aws_region_from_s3_uri('s3://simple-bucket/path')\n        ''\n    \"\"\"\n    # Parse the S3 URI\n    parsed = urlparse(s3_uri)\n    bucket_name = parsed.netloc\n    \n    # AWS regions follow the pattern: region-code (e.g., us-east-1, eu-west-2)\n    # Valid region patterns: {area}-{direction}-{number}\n    # Examples: us-east-1, eu-west-2, ap-southeast-1, ca-central-1, sa-east-1\n    \n    aws_region_pattern = r'(us|eu|ap|ca|sa|cn|me|af)-[a-z]+-\\d+$'\n    \n    # Split bucket name by hyphens and check from right to left\n    parts = bucket_name.split('-')\n    \n    # Try to find region by checking if last 3 parts match region pattern\n    if len(parts) >= 3:\n        potential_region = '-'.join(parts[-3:])\n        if re.match(aws_region_pattern, potential_region):\n            return potential_region\n    \n    return \"\"\n\n\ndef extract_aws_region_from_s3_uri_v2(s3_uri: str) -> str:\n    \"\"\"\n    Alternative implementation using a comprehensive AWS regions list.\n    \n    Args:\n        s3_uri: S3 URI in format 's3://bucket-name/path'\n        \n    Returns:\n        The AWS region string, or an empty string if no region is found\n    \"\"\"\n    # Comprehensive list of all AWS regions\n    aws_regions = {\n        # US Regions\n        'us-east-1', 'us-east-2', 'us-west-1', 'us-west-2',\n        # EU Regions\n        'eu-west-1', 'eu-west-2', 'eu-west-3', 'eu-central-1', 'eu-north-1',\n        # Asia Pacific\n        'ap-south-1', 'ap-northeast-1', 'ap-northeast-2', 'ap-northeast-3',\n        'ap-southeast-1', 'ap-southeast-2',\n        # Canada\n        'ca-central-1',\n        # South America\n        'sa-east-1',\n        # China\n        'cn-north-1', 'cn-northwest-1',\n        # Middle East\n        'me-south-1',\n        # Africa\n        'af-south-1'\n    }\n    \n    parsed = urlparse(s3_uri)\n    bucket_name = parsed.netloc\n    \n    # Check all possible region combinations from right to left\n    parts = bucket_name.split('-')\n    \n    for i in range(len(parts), 0, -1):\n        potential_region = '-'.join(parts[i-3:i]) if i >= 3 else None\n        if potential_region and potential_region in aws_regions:\n            return potential_region\n    \n    return \"\"\n\n\n# Test cases\nif __name__ == \"__main",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an S3 bucket URI (e.g., 's3://my-bucket-us-west-2/path'). The region is the last hyphen-separated component before the final path segment."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Policy for S3 Read Access\n\nHere's a JSON object representing an IAM policy that allows reading from and listing an S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    },\n    {\n      \"Sid\": \"ReadObjectsFromBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    }\n  ]\n}\n```\n\n## Explanation\n\n**Version:** `2012-10-17` - Standard IAM policy language version\n\n**Statement 1 - ListBucketContents:**\n- `Action`: `s3:ListBucket` - Allows listing the bucket contents\n- `Resource`: `arn:aws:s3:::my-data-bucket` - Applied to the bucket itself\n\n**Statement 2 - ReadObjectsFromBucket:**\n- `Action`: `s3:GetObject` - Allows reading/downloading objects\n- `Resource`: `arn:aws:s3:::my-data-bucket/*` - Applied to all objects in the bucket (note the `/*`)\n\n## Key Points\n\n- The two statements use different resources because `ListBucket` operates on the bucket, while `GetObject` operates on objects within it\n- The `/*` in the second resource ARN means \"all objects\" in the bucket\n- This policy is read-only and doesn't allow uploads, deletions, or modifications",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that allows a user to read all objects from an S3 bucket named 'my-data-bucket' and list bucket contents."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Security Group ID Regex Validator\n\nHere's a regular expression that validates AWS EC2 security group ID formats:\n\n```regex\n^sg-([0-9a-f]{17}|[0-9a-f]{8})$\n```\n\n## Explanation\n\n| Component | Description |\n|-----------|-------------|\n| `^` | Start of string |\n| `sg-` | Literal prefix required for all security group IDs |\n| `(...)` | Grouping for alternation options |\n| `[0-9a-f]{17}` | Either 17 hexadecimal characters (EC2-VPC format) |\n| `\\|` | OR operator |\n| `[0-9a-f]{8}` | Or 8 hexadecimal characters (EC2-Classic format) |\n| `$` | End of string |\n\n## Usage Examples\n\n### Python\n```python\nimport re\n\npattern = r'^sg-([0-9a-f]{17}|[0-9a-f]{8})$'\n\n# Valid examples\nprint(re.match(pattern, 'sg-0123456789abcdef0'))  # \u2713 Valid (17 chars)\nprint(re.match(pattern, 'sg-12345678'))            # \u2713 Valid (8 chars)\n\n# Invalid examples\nprint(re.match(pattern, 'sg-invalid'))             # \u2717 Invalid\nprint(re.match(pattern, 'ec2-12345678'))           # \u2717 Invalid prefix\nprint(re.match(pattern, 'sg-0123456789'))          # \u2717 Wrong length\n```\n\n### JavaScript\n```javascript\nconst pattern = /^sg-([0-9a-f]{17}|[0-9a-f]{8})$/;\n\nconsole.log(pattern.test('sg-0123456789abcdef0')); // true\nconsole.log(pattern.test('sg-12345678'));         // true\nconsole.log(pattern.test('sg-invalid'));          // false\n```\n\n## Notes\n\n- **Case Sensitivity**: The regex uses lowercase `[0-9a-f]`. For case-insensitive matching, use `[0-9a-fA-F]` or add the `i` flag\n- **VPC vs EC2-Classic**: \n  - 17 hex chars = Modern EC2-VPC format (recommended)\n  - 8 hex chars = Legacy EC2-Classic format",
#     "test_case": {
#       "task": "Write a regular expression that validates an AWS EC2 security group ID format (starts with 'sg-' followed by 17 hexadecimal characters or 8 hexadecimal characters)."
#     },
#     "score": 10
#   }
# ]
